# %% [markdown]
# __Извлечение структурированных данных из текста__
#
# Евгений Борисов <esborisov@sevsu.ru>
#
# синтаксический парсер Yargy пакета Natasha

# %% [markdown]
# ---

# %% [markdown]
# Александр Кукушкин
# Yargy-парсер и библиотека Natasha. Извлечения структурированной информации из текстов на русском языке.
# https://habr.com/ru/post/349864/

# %% [markdown]
# Александр Кукушкин
# Yargy парсер. Извлечение структурированной информации из текстов на русском языке.
# PyData Moscow 2018
# https://www.youtube.com/watch?v=NQxzx0qYgK8

# %% [markdown]
# https://telegram.me/natural_language_processing

# %% [markdown]
# ---

# %%
lines = [
 '1 пучок петрушки',
 '● Молоко или вода - 2 стакана',
 '20 г миндаль ',
 'Яйцо - 1 шт.',
 '400 г варёного сгущённого молока',
 '3 ст.л. красного винного уксуса ',
 '🔹 Картофель - 600-700 г',
 '- 700 гр свинины',
 'Вода - 0,5 л',
 '● Куриная грудка - 1 шт.',
 'Лимонный сок - 2 ст. л',
 'Сыворотка - 1 ч. л.',
 'Сыр - 100 г ',
 '- мука 2 стакана ',
 '● 3 ст. л. сливок',
 '200 гр фарша',
 '- мука - 120 гр,',
 'Лимонный сок - 20г. ',
 'Корень имбиря маринованный 7 г ',
 'соль - 1/2 ч. ложки ',
 '400 г однородного творога;',
 '🔹 5 средних варёных картофелин',
 'Сахар - 0,5 стак.',
 '-150 г сахара',
 'Говядина 500 г ',
 'Кунжут 1 ст. л. ',
 'Йогурт натуральный - 2 ст. л',
 'Лук - 100 г ',
 'Оливковое масло 3 ст.л.; ',
 '-яблоки 6-8 штук среднего размера',
 '- какао 100 г ',
 '●1 ч. л. ванильной эссенции,',
 'Какао-порошок - 50 гр., ',
 '● соль (1/2 ч. ложки).',
 'Уксус(6%)-2ст л',
 '2 ст. л. лимонного сока',
 '• уксус, 60-70 мл (яблочный) ',
 '● 300-400гр .куриной печени, ',
 ' 100 мл коньяка,',
 'говядина - 350 Грамм (для фарша) ',
 'Яйца - 3 шт.',
 '• Сыр - 100 г (у нас российский) ',
 'Лук зеленый 5 стебелей ',
 '- сливочное масло - 90 гр,',
 '● Колбаса копч. - 100 гр.',
 '1-2 ч. л. натёртого имбиря',
 '- морковь 1шт,',
 '-Фасоль красная в собственном соку - 200 г',
 'Лук репчатый - 3 шт.',
 '-100 грамм кефира (либо 2-3 ложки майонеза) ',
 ' Соль >20 г;',
 '● вода - 1/2 стакана',
 'яйца - 3 шт. ',
 '~1,2 кг. куриного фарша ',
 '●200г муки',
 'Молоко - 1 ст. л. ',
 '2 яйца',
 '2 банана',
 '● яйца - 2 шт,',
 'Лаваш прямоугоьный - 1 Штука',
 'Лёд - 2 стакана,',
 'Выход: 20 г.',
 '- Яйцо куриное 5 шт.',
 '-Ветчина 150 гр ',
 'творог 200 гр',
 'сахар ванильный - 1 пакетик ',
 ' Сода - 1 ч.ложка,',
 '● 80-100 г сливочного маслица',
 '500 г куриного филе',
 '100 г сливок 35% жирности (брал 20%) ',
 '- сахар 1 стакан ',
 '● Яйцо - 1 шт.',
 'Рубленные грецкие орехи - 50 г ',
 '● Помидоры спелые - 2 кг',
 '● Масло растительное рафинированное - 50 г',
 '• курица (филе) 500 г',
 '● 150 г копченой колбасы; ',
 '-1 кг. - сахара,',
 'Болгарский перец - 3 шт.',
 'Крахмал - 2 столовые ложки',
 'Сухари (молотые) - 3-4 ст. л.',
 '● Кофе с сахаром - 1 стакан',
 'масло растительное - 1 гр.',
 '● Нежирная свинина, 300-400г, ',
 '🔹 100 г тертого сыра',
 'Яйца - 2 шт',
 '● Картофельная мука - 1 стакан',
 'Подсолнечное масло - 50 мл',
 '75 г сливочного масла ',
 '● 500 гр. печенья ',
 '🔹 2 яйца',
 '● 200г крабовых палочек ',
 '● картошка - 0,5 кг.',
 '● 120 г сметаны (15-20%)',
 '1 кабачок (400 гр)',
 '-кефир - 1,5 стакана;',
 ' Масло растительное 1 ст.л.;',
 '● 150 г. муки ',
 '-0,5 ч. л. соды;',
 'Томатная паста - 2 ст. ложки',
]

# %% [markdown]
# ---

# %%
from ipymarkup import show_span_box_markup as show_markup

from yargy import Parser
from yargy import rule
from yargy import or_
from yargy.predicates import eq
from yargy.predicates import in_
from yargy.predicates import type as type_
# from yargy.predicates import normalized
from yargy.predicates import gram
from yargy.pipelines import morph_pipeline
from yargy.interpretation import fact

# %%
Measure = fact(
    'Measure',
    ['amount','unit'],
)
Product = fact(
    'Product',
    ['name','modifiers'],
)
Ingradient = fact(
    'Ingradient',
    ['measure','product'],
)

# %%
INT = type_('INT')

DIGIT = rule(INT).interpretation(Measure.amount.custom(int))

FLOAT = rule(
    INT,
    in_(',.'),
    INT
).interpretation(Measure.amount.custom(lambda _: float(_.replace(',','.'))))


from fractions import Fraction

def parse_fraction(value):
    a,b = value.split('/')
    return Fraction( int(a),int(b) )

FRACTION = rule(
    INT,
    eq('/'),
    INT
).interpretation(Measure.amount.custom(parse_fraction))
 
def parse_range(value):
    a,b = value.split('-')
    return (int(a),int(b))

RANGE = rule(
    INT,
    eq('-'),
    INT
).interpretation(Measure.amount.custom(parse_range))


AMOUNT = or_(
    DIGIT,
    FLOAT,
    FRACTION,
    RANGE,
)

UNIT_NAME = morph_pipeline([
    'г',
    'гр',
    'грaмм',
    'кг',
    'чаш',
    'шт',
    'л',
    'литр',
    'мл',
    'миллилитр',    
    'ст.л',
    'ст.ложка',
    'ч.ложка',
    'ч.л',
    'чайная ложка',
    'стакан', 
    'cт',
    'перо',
    'пучок',
    'горсть',
]).interpretation(Measure.unit.normalized())

UNIT = rule(
    UNIT_NAME,
    in_('.;').optional(),
)


MEASURE = rule( 
    AMOUNT, 
    UNIT.optional(), 
).interpretation(Measure)

# грамемы
# ADJF - прилагательное
# NOUN - существительное

ADJF = gram('ADJF')
NOUN = gram('NOUN')

MODIFIER = ADJF.repeatable().interpretation(Product.modifiers.normalized())
PRODUCT = rule(
    MODIFIER.optional(),
    NOUN.interpretation(Product.name.normalized()),
    MODIFIER.optional(),
).interpretation(Product)

SEP = in_('-:,')

INGRADIENT = or_(
    rule(
        PRODUCT.interpretation(Ingradient.product),
        SEP.optional(),
        MEASURE.interpretation(Ingradient.measure),
    ),
    rule(
        MEASURE.interpretation(Ingradient.measure),
        SEP.optional(),
        PRODUCT.interpretation(Ingradient.product),
    ),
).interpretation(Ingradient)

# %%
# INGRADIENT.normalized.as_bnf

# %%
parser = Parser(INGRADIENT)

# %%
for line in lines:
    matches = list(parser.findall(line))
    spans = [_.span for _ in matches]
    print('_'*90)
    show_markup(line, spans)
    if matches:
        match = matches[0]
        display(match.tree.as_dot)
        display(match.fact)
# Out:
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1 пучок петрушки</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='пучок'
#     ),
#     product=Product(
#         name='петрушка',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● Молоко или <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">вода - 2 стакана</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='стакан'
#     ),
#     product=Product(
#         name='вода',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">20 г миндаль</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=20,
#         unit='г'
#     ),
#     product=Product(
#         name='миндаль',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Яйцо - 1 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">400 г варёного</span> сгущённого молока</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=400,
#         unit=None
#     ),
#     product=Product(
#         name='г',
#         modifiers='варёный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">3 ст.л. красного винного уксуса</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='уксус',
#         modifiers='красный винный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">🔹 <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Картофель - 600-700 г</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(600,
#          700),
#         unit='г'
#     ),
#     product=Product(
#         name='картофель',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">700 гр свинины</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=700,
#         unit='гр'
#     ),
#     product=Product(
#         name='свинин',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Вода - 0,5 л</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=0.5,
#         unit='л'
#     ),
#     product=Product(
#         name='вода',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Куриная грудка - 1 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='шт'
#     ),
#     product=Product(
#         name='грудка',
#         modifiers='куриный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лимонный сок - 2 ст. л</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='сок',
#         modifiers='лимонный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Сыворотка - 1 ч. л.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ч.л'
#     ),
#     product=Product(
#         name='сыворотка',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Сыр - 100 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='г'
#     ),
#     product=Product(
#         name='сыр',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">мука 2 стакана</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='стакан'
#     ),
#     product=Product(
#         name='мука',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">3 ст. л. сливок</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='сливка',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">200 гр фарша</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=200,
#         unit='гр'
#     ),
#     product=Product(
#         name='фарш',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">мука - 120 гр</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=120,
#         unit='гр'
#     ),
#     product=Product(
#         name='мука',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лимонный сок - 20г.</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=20,
#         unit='г'
#     ),
#     product=Product(
#         name='сок',
#         modifiers='лимонный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Корень имбиря маринованный <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">7 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=7,
#         unit=None
#     ),
#     product=Product(
#         name='г',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">соль - 1/2 ч. ложки</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=Fraction(1, 2),
#         unit='ч.ложка'
#     ),
#     product=Product(
#         name='соль',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">400 г однородного творога</span>;</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=400,
#         unit='г'
#     ),
#     product=Product(
#         name='творог',
#         modifiers='однородный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">🔹 <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">5 средних варёных картофелин</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=5,
#         unit=None
#     ),
#     product=Product(
#         name='картофелина',
#         modifiers='средний варёный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Сахар - 0,5</span> стак.</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=0.5,
#         unit=None
#     ),
#     product=Product(
#         name='сахар',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">150 г сахара</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=150,
#         unit='г'
#     ),
#     product=Product(
#         name='сахар',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Говядина 500 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=500,
#         unit='г'
#     ),
#     product=Product(
#         name='говядина',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Кунжут 1 ст. л.</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='кунжут',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Йогурт натуральный - 2 ст. л</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='йогурт',
#         modifiers='натуральный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лук - 100 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='г'
#     ),
#     product=Product(
#         name='лук',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Оливковое масло 3 ст.л.</span>; </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='оливковый'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">яблоки 6</span>-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">8 штук среднего</span> размера</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=6,
#         unit=None
#     ),
#     product=Product(
#         name='яблоко',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">какао 100 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='г'
#     ),
#     product=Product(
#         name='какао',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">●<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1 ч. л. ванильной эссенции</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ч.л'
#     ),
#     product=Product(
#         name='эссенция',
#         modifiers='ванильный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Какао-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">порошок - 50 гр.</span>, </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=50,
#         unit='гр'
#     ),
#     product=Product(
#         name='порошок',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● соль (<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1/2 ч</span>. ложки).</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=Fraction(1, 2),
#         unit=None
#     ),
#     product=Product(
#         name='ч',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Уксус(6%)-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2ст л</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit=None
#     ),
#     product=Product(
#         name='ст',
#         modifiers='л'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2 ст. л. лимонного сока</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='сок',
#         modifiers='лимонный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">• <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">уксус, 60-70 мл</span> (яблочный) </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(60,
#          70),
#         unit='мл'
#     ),
#     product=Product(
#         name='уксус',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">300-400гр .куриной печени</span>, </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(300,
#          400),
#         unit='гр'
#     ),
#     product=Product(
#         name='печень',
#         modifiers='куриный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">100 мл коньяка</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='мл'
#     ),
#     product=Product(
#         name='коньяк',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">говядина - 350</span> Грамм (для фарша) </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=350,
#         unit=None
#     ),
#     product=Product(
#         name='говядина',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Яйца - 3 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">• <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Сыр - 100 г</span> (у нас российский) </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='г'
#     ),
#     product=Product(
#         name='сыр',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лук зеленый 5</span> стебелей </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=5,
#         unit=None
#     ),
#     product=Product(
#         name='лук',
#         modifiers='зелёный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сливочное масло - 90 гр</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=90,
#         unit='гр'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='сливочный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● Колбаса копч. - <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">100 гр</span>.</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit=None
#     ),
#     product=Product(
#         name='гр',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1-2 ч</span>. л. натёртого имбиря</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(1,
#          2),
#         unit=None
#     ),
#     product=Product(
#         name='ч',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">морковь 1шт</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='шт'
#     ),
#     product=Product(
#         name='морковь',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-Фасоль красная в <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">собственном соку - 200 г</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=200,
#         unit='г'
#     ),
#     product=Product(
#         name='сок',
#         modifiers='собственный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лук репчатый - 3 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='шт'
#     ),
#     product=Product(
#         name='лук',
#         modifiers='репчатый'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">100 грамм</span> кефира (либо <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2-3 ложки</span> майонеза) </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit=None
#     ),
#     product=Product(
#         name='грамм',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"> Соль &gt;<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">20 г</span>;</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=20,
#         unit=None
#     ),
#     product=Product(
#         name='г',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">вода - 1/2 стакана</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=Fraction(1, 2),
#         unit='стакан'
#     ),
#     product=Product(
#         name='вода',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">яйца - 3 шт.</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">~<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1,2 кг. куриного фарша</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1.2,
#         unit='кг'
#     ),
#     product=Product(
#         name='фарш',
#         modifiers='куриный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">●<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">200г муки</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=200,
#         unit='г'
#     ),
#     product=Product(
#         name='мука',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Молоко - 1 ст. л.</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='молоко',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2 яйца</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit=None
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2 банана</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit=None
#     ),
#     product=Product(
#         name='банан',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">яйца - 2 шт</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лаваш прямоугоьный - 1</span> Штука</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit=None
#     ),
#     product=Product(
#         name='лаваш',
#         modifiers='прямоугоьный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Лёд - 2 стакана</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='стакан'
#     ),
#     product=Product(
#         name='лёд',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Выход: 20 г.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=20,
#         unit='г'
#     ),
#     product=Product(
#         name='выход',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Яйцо куриное 5 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=5,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers='куриный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Ветчина 150 гр</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=150,
#         unit='гр'
#     ),
#     product=Product(
#         name='ветчина',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">творог 200 гр</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=200,
#         unit='гр'
#     ),
#     product=Product(
#         name='творог',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сахар ванильный - 1</span> пакетик </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit=None
#     ),
#     product=Product(
#         name='сахар',
#         modifiers='ванильный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Сода - 1 ч.ложка</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ч.ложка'
#     ),
#     product=Product(
#         name='сода',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">80-100 г сливочного маслица</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(80,
#          100),
#         unit='г'
#     ),
#     product=Product(
#         name='маслице',
#         modifiers='сливочный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">500 г куриного филе</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=500,
#         unit='г'
#     ),
#     product=Product(
#         name='филе',
#         modifiers='куриный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">100 г</span> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сливок 35</span>% жирности (брал 20%) </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit=None
#     ),
#     product=Product(
#         name='г',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">- <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сахар 1 стакан</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='стакан'
#     ),
#     product=Product(
#         name='сахар',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Яйцо - 1 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Рубленные <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">грецкие орехи - 50 г</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=50,
#         unit='г'
#     ),
#     product=Product(
#         name='орех',
#         modifiers='грецкий'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Помидоры спелые - 2 кг</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='кг'
#     ),
#     product=Product(
#         name='помидор',
#         modifiers='спелый'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Масло растительное рафинированное - 50 г</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=50,
#         unit='г'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='растительный рафинированный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">• курица (филе) <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">500 г</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=500,
#         unit=None
#     ),
#     product=Product(
#         name='г',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">150 г копченой колбасы</span>; </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=150,
#         unit='г'
#     ),
#     product=Product(
#         name='колбаса',
#         modifiers='копчёный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1 кг. - сахара</span>,</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='кг'
#     ),
#     product=Product(
#         name='сахар',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Болгарский перец - 3 шт.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=3,
#         unit='шт'
#     ),
#     product=Product(
#         name='перец',
#         modifiers='болгарский'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Крахмал - 2</span> столовые ложки</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit=None
#     ),
#     product=Product(
#         name='крахмал',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">Сухари (молотые) - <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">3-4 ст</span>. л.</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(3,
#          4),
#         unit=None
#     ),
#     product=Product(
#         name='ст',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● Кофе с <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">сахаром - 1 стакан</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='стакан'
#     ),
#     product=Product(
#         name='сахар',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">масло растительное - 1 гр.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='гр'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='растительный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Нежирная свинина, 300-400г</span>, </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=(300,
#          400),
#         unit='г'
#     ),
#     product=Product(
#         name='свинина',
#         modifiers='нежирный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">🔹 <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">100 г тертого сыра</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=100,
#         unit='г'
#     ),
#     product=Product(
#         name='сыр',
#         modifiers='тёртый'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Яйца - 2 шт</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='шт'
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Картофельная мука - 1 стакан</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='стакан'
#     ),
#     product=Product(
#         name='мука',
#         modifiers='картофельный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Подсолнечное масло - 50 мл</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=50,
#         unit='мл'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='подсолнечный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">75 г сливочного масла</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=75,
#         unit='г'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='сливочный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">500 гр. печенья</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=500,
#         unit='гр'
#     ),
#     product=Product(
#         name='печение',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">🔹 <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">2 яйца</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit=None
#     ),
#     product=Product(
#         name='яйцо',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">200г крабовых палочек</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=200,
#         unit='г'
#     ),
#     product=Product(
#         name='палочка',
#         modifiers='крабовый'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">картошка - 0,5 кг.</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=0.5,
#         unit='кг'
#     ),
#     product=Product(
#         name='картошка',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">120 г сметаны</span> (15-20%)</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=120,
#         unit='г'
#     ),
#     product=Product(
#         name='сметана',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">1 кабачок</span> (<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">400 гр</span>)</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit=None
#     ),
#     product=Product(
#         name='кабачок',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">кефир - 1,5 стакана;</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1.5,
#         unit='стакан'
#     ),
#     product=Product(
#         name='кефир',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"> <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Масло растительное 1 ст.л.</span>;</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=1,
#         unit='ст.л'
#     ),
#     product=Product(
#         name='масло',
#         modifiers='растительный'
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">● <span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">150 г. муки</span> </div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=150,
#         unit='г'
#     ),
#     product=Product(
#         name='мука',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap">-<span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">0,5 ч. л. соды</span>;</div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=0.5,
#         unit='ч.л'
#     ),
#     product=Product(
#         name='сода',
#         modifiers=None
#     )
# )
# __________________________________________________________________________________________
# <div class="tex2jax_ignore" style="white-space: pre-wrap"><span style="padding: 2px; border-radius: 4px; border: 1px solid #bbdefb; background: #e3f2fd">Томатная паста - 2 ст. ложки</span></div>
# Graph(nodes=[...], edges=[...])
# Ingradient(
#     measure=Measure(
#         amount=2,
#         unit='ст.ложка'
#     ),
#     product=Product(
#         name='паста',
#         modifiers='томатный'
#     )
# )

# %% [markdown]
# ---

# %%
# предопределённые rules для извлечения имён
# from natasha import NameExtractor

# %% [markdown]
# ---

# %%
# %run -n main.py

# %%
# !pip install graphviz
